# %%
Name = input("What is the name of the Blackhole :")
Mass_of_Blackhole= float(input("What is the mass of the BlackHole(in Solar Masses) :"))
Radius = Mass_of_Blackhole *2.953
print(f"{Name} forms a  blackhole of size {Radius}(in km)")
# Out:
# what is the name of the Blackhole : Saggitarius A*
# what is the mass of the BlackHole(in Solar Masses) : 4154000
# Saggitarius A* will form a  blackhole of size 12266762.0(in km)
