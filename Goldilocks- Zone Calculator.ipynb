# %%
import math
Star = input("Enter Star name: ")
planet = input("Enter planet name: ")
distance = float(input(f"Enter distance of {planet} from {Star}in AU: "))
luminosity = float(input(f"Enter luminosity of {Star} (compared to the Sun): "))

if distance <= 0 or luminosity <= 0:
    print("Values must be positive.")
else:
    inner_allowed = 0.95 * math.sqrt(luminosity)
    outer_allowed= 1.37 * math.sqrt(luminosity)
    
    if distance < inner_allowed:
        print(f"{planet} is too hot! The inner boundary is {inner_allowed:.2f} AU.")
    elif inner_allowed<= distance <= :
        print(f"Success! {planet} is in the Habitable Zone of {Star}.")
    else:
        print(f"{planet} is too cold! The outer boundary is { outer_allowed:.2f} AU.")
